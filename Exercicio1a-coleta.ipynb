# %% [markdown]
# ## Exercício 1

# %% [markdown]
# Importando API do Youtube

# %%
from pyyoutube import Api
from datetime import datetime

api = Api(api_key="AIzaSyBol28LEtQ-rYLBGPDYyZALj86Wths_hFI")

# %% [markdown]
# Obtendo os 50 vídeos com a palavra chave eleição

# %%
search = api.search_by_keywords(q='eleição', count=50, search_type=["video"], published_after='2022-10-29T00:00:00Z', published_before='2022-10-31T00:00:00Z', location='-23.5505,-46.6333', location_radius='50km')

# %% [markdown]
# Exibindo resultados da primeira busca e procurando o vídeo com mais comentários

# %%
most_commented_video = None
max_comments = 0

for video in search.items:
    video_info = api.get_video_by_id(video_id=video.id.videoId)
    comments = video_info.items[0].statistics.commentCount
    if comments == None:
        comments = 0

    if comments > max_comments:
        most_commented_video = video_info
        max_comments = comments
    
    print(video.snippet.title)
    print(video.snippet.channelTitle)
    print(video.snippet.publishedAt)
    print("=====================================")
    print()
# Out:
# Sobre Violência, Abuso, Eleição e Democracia,  por Alfredo Attié
# Alfredo Attié
# 2022-10-30T04:35:31Z
# ...
#
# Eleições #eleições #eleições2022
# Café com Fredinho
# 2022-10-30T10:25:27Z
# ...
#
# A PEDIDOS SOBRE O QUE VEM APOS RESULTADO ELEIÇÃO  2022 ALGUNS ACONTECIMENTOS MEU ZAP 13991115050
# CIGANA KATRYNA ROSAAMARELA
# 2022-10-30T01:52:38Z
# ...
#
# NA ELEIÇÃO DE HOJE, FAMOSOS PROTESTAM E DECLARAM VOTO PARA PAULO GUSTAVO.
# Mineirinho do Piseiro
# 2022-10-30T16:28:13Z
# ...
#
# VALORANT - DOMINGO DE ELEIÇÃO 2022
# JhnOliveiira
# 2022-10-30T19:30:29Z
# ...
#
# Borra Eleição e Futuro Mandato
# ler a borra de café
# 2022-10-30T15:32:07Z
# ...
#
# 30/10/2022 Eleição que ficará na história!
# DRA PATRII ROMANO
# 2022-10-29T20:56:16Z
# ...
#
# Cidade de Mongaguá sp - Litoral Sul de São Paulo
# Natureza , Praia e Trilhas
# 2022-10-30T19:16:39Z
# ...
#
# Tribunal Regional Eleitoral de São Paulo
# TRE São Paulo
# 2022-10-30T20:01:10Z
# ...
#
# Citações e frases para Bolsonaro e Lula. Eleições 2022! Qual a sua escolha Deixe Comentários.
# ...

# %% [markdown]
# Exibindo vídeo com mais comentários

# %%
if most_commented_video:
    print(f"Vídeo com mais comentários: {most_commented_video.items[0].snippet.title}")
    print(f"ID do vídeo: {most_commented_video.items[0].id}")
    print(f"Data de publicação: {most_commented_video.items[0].snippet.publishedAt}")
    print(f"Número de comentários: {most_commented_video.items[0].statistics.commentCount}")
else:
    print("Nenhum vídeo encontrado no período especificado.")
# Out:
# Vídeo com mais comentários: DEBATE NA GLOBO: LULA CHAMA BOLSONARO DE DESCOMPENSADO | BOLSONARO SE IRRITA E ATACA BONNER E GLOBO
# ID do vídeo: buWjQ87OQM0
# Data de publicação: 2022-10-29T01:19:15Z
# Número de comentários: 399

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Importando biblioteca

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Adicionando a URL a ser buscada

# %%
url = "https://www.apontador.com.br/local/sp/campinas/faculdades_e_universidades/88Q2E372/"

req = requests.get(url)

soup = BeautifulSoup(req.content, 'html.parser')

# %% [markdown]
# Definindo containers e juntando os comentários com a quantidade de estrelas

# %%
container_reviews = soup.find_all('div', class_='store-comments__text')

container_stars = soup.find_all('div', class_='rate-stars')

list_container_stars = []

for container in container_stars:
    ul = container.find_all('ul')
    for lis in ul:
        li = lis.find_all('li')
        list_container_stars.append(li)

list_container_stars.pop(0)

quantity_stars = []
for stars in range (len(list_container_stars)):
    quantity_stars.append(len(list_container_stars) * 0 + 5)

for list_li in list_container_stars:
    for li in list_li:
        img = li.find('img')
        if img:
            if 'unchecked' in img['src']:
                quantity_stars[stars] -= 1

for review, star in zip(container_reviews, quantity_stars):
    print(f"Estrelas: {star}")
    print(f"Comentário: {review.text}")
    print("=====================================")
    print()
# Out:
# Estrelas: 5
# Comentário:
# ...

# %% [markdown]
# ## Exercício 3

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome()

driver.get("https://www.uol.com.br/")

total_height = driver.execute_script("return document.body.scrollHeight")

scroll_increment = 200  # pixels
scroll_delay = 0.1  # segundos

for i in range(0, total_height, scroll_increment):
    driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
    time.sleep(scroll_delay)

    end_of_page = driver.execute_script("return window.pageYOffset + window.innerHeight >= document.body.scrollHeight")

    if end_of_page:
        break

time.sleep(5)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[1], line 17
#      14 driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
#      15 time.sleep(scroll_delay)
# ---> 17 end_of_page = driver.execute_script("return window.pageYOffset + window.innerHeight >= document.body.scrollHeight")
#      19 if end_of_page:
#      20     break
#
# File c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:407, in WebDriver.execute_script(self, script, *args)
#     404 converted_args = list(args)
#     405 command = Command.W3C_EXECUTE_SCRIPT
# --> 407 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
# ...
